# %%
import math
data = pd.read_csv('/kaggle/input/house-price-tehran-iran/housePrice.csv')

# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
column1 = data.loc[:,['Price']]
column1 = column1.values
# Out:
# [array([1.85e+09]),
#  array([1.85e+09]),
#  array([5.5e+08]),
#  array([9.025e+08]),
#  array([7.e+09]),
#  array([2.05e+09]),
#  array([6.e+08]),
#  array([2.15e+09]),
#  array([4.93e+08]),
#  array([2.37e+09]),
#  array([2.45e+09]),
#  array([2.1e+09]),
#  array([1.69e+09]),
#  array([1.1e+10]),
#  array([5.e+09]),
#  array([5.7e+08]),
#  array([6.7e+09]),
#  array([1.45e+09]),
#  array([6.4e+09]),
#  array([1.39e+09]),
#  array([7.e+09]),
#  array([2.5e+09]),
#  array([1.88e+09]),
#  array([2.277e+09]),
#  array([7.15e+09]),
#  array([1.4945e+10]),
#  array([1.771e+09]),
#  array([4.059e+09]),
#  array([6.3e+08]),
#  array([3.2e+09]),
#  array([1.5e+09]),
#  array([2.2e+09]),
#  array([7.872e+09]),
#  array([2.35e+09]),
#  array([2.5e+09]),
#  array([2.15e+09]),
#  array([2.15e+09]),
#  array([3.75e+09]),
#  array([5.25e+09]),
#  array([4.83e+09]),
#  array([3.4e+09]),
#  array([3.85e+09]),
#  array([1.2e+09]),
#  array([2.65e+09]),
#  array([5.e+09]),
#  array([4.75e+09]),
# ...

# %%
column2 = data.loc[:,['Price(USD)']]
column2 = column2.values
column2
# Out:
# array([[ 61666.67],
#        [ 61666.67],
#        [ 18333.33],
#        ...,
#        [ 12166.67],
#        [186666.67],
#        [ 12000.  ]])

# %%
def euclidean_distance(a, b):
 return sqrt(sum((e1-e2)**2 for e1, e2 in zip(a,b)))
dist = euclidean_distance(column1, column2)
dist
# Out:
# 572782551783.2454

# %%
def minkowski_distance(a, b, p):
 return sum(abs(e1-e2)**p for e1, e2 in zip(a,b))**(1/p)

# calculate distance (p=1)
dist = minkowski_distance(column1, column2, 1)
print(dist)
# calculate distance (p=2)
dist = minkowski_distance(column1, column2, 2)
print(dist)
# Out:
# [1.86434185e+13]
# [5.72782552e+11]

# %%
from numpy.linalg import norm
array1 = np.array(column1).flatten()
array1
# Out:
# array([1.85e+09, 1.85e+09, 5.50e+08, ..., 3.65e+08, 5.60e+09, 3.60e+08])

# %%
array2 = np.array(column2).flatten()
array2
# Out:
# array([ 61666.67,  61666.67,  18333.33, ...,  12166.67, 186666.67,
#         12000.  ])

# %%
mycosine = np.dot(array1,array2)/(norm(array1)*norm(array2))
mycosine
# Out:
# 0.9999999999999987

# %%
np.corrcoef(array1, array2)
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
import seaborn as sns
sns.distplot([dist,mycosine])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
